# %%
import pandas as pd

# %%
df = pd.read_csv("amazon.csv")
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
df.shape
# Out:
# (1465, 16)

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   str
#  1   product_name         1465 non-null   str
#  2   category             1465 non-null   str
#  3   discounted_price     1465 non-null   str
#  4   actual_price         1465 non-null   str
#  5   discount_percentage  1465 non-null   str
#  6   rating               1465 non-null   str
#  7   rating_count         1463 non-null   str
#  8   about_product        1465 non-null   str
#  9   user_id              1465 non-null   str
#  10  user_name            1465 non-null   str
#  11  review_id            1465 non-null   str
#  12  review_title         1465 non-null   str
#  13  review_content       1465 non-null   str
#  14  img_link             1465 non-null   str
#  15  product_link         1465 non-null   str
# dtypes: str(16)
# ...

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["discounted_price"] = df["discounted_price"].str.replace("₹", "", regex=False)
df["discounted_price"] = df["discounted_price"].str.replace(",", "", regex=False)
df["discounted_price"] = df["discounted_price"].astype(float)

df["actual_price"] = df["actual_price"].str.replace("₹", "", regex=False)
df["actual_price"] = df["actual_price"].str.replace(",", "", regex=False)
df["actual_price"] = df["actual_price"].astype(float)

# %%
df[["discounted_price", "actual_price"]].head()
# Out:
#    discounted_price  actual_price
# 0             399.0        1099.0
# 1             199.0         349.0
# 2             199.0        1899.0
# 3             329.0         699.0
# 4             154.0         399.0

# %%
df["discount_percentage"] = df["discount_percentage"].str.replace("%", "", regex=False)
df["discount_percentage"] = df["discount_percentage"].astype(float)

df["discount_percentage"].head()
# Out:
# 0    64.0
# 1    43.0
# 2    90.0
# 3    53.0
# 4    61.0
# Name: discount_percentage, dtype: float64

# %%
df["rating"] = pd.to_numeric(df["rating"], errors="coerce")

df["rating"].head()
# Out:
# 0    4.2
# 1    4.0
# 2    3.9
# 3    4.2
# 4    4.2
# Name: rating, dtype: float64

# %%
df["rating"].isnull().sum()
# Out:
# np.int64(1)

# %%
df["rating_count"] = df["rating_count"].str.replace(",", "", regex=False)
df["rating_count"] = df["rating_count"].astype(float)

df["rating_count"].head()
# Out:
# 0    24269.0
# 1    43994.0
# 2     7928.0
# 3    94363.0
# 4    16905.0
# Name: rating_count, dtype: float64

# %%
df["rating_count"].isnull().sum()
# Out:
# np.int64(2)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   str
#  1   product_name         1465 non-null   str
#  2   category             1465 non-null   str
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1464 non-null   float64
#  7   rating_count         1463 non-null   float64
#  8   about_product        1465 non-null   str
#  9   user_id              1465 non-null   str
#  10  user_name            1465 non-null   str
#  11  review_id            1465 non-null   str
#  12  review_title         1465 non-null   str
#  13  review_content       1465 non-null   str
#  14  img_link             1465 non-null   str
#  15  product_link         1465 non-null   str
# ...

# %%
df.describe()
# Out:
#        discounted_price   actual_price  discount_percentage       rating  \
# count       1465.000000    1465.000000          1465.000000  1464.000000
# mean        3125.310874    5444.990635            47.691468     4.096585
# std         6944.304394   10874.826864            21.635905     0.291674
# min           39.000000      39.000000             0.000000     2.000000
# 25%          325.000000     800.000000            32.000000     4.000000
# 50%          799.000000    1650.000000            50.000000     4.100000
# 75%         1999.000000    4295.000000            63.000000     4.300000
# max        77990.000000  139900.000000            94.000000     5.000000
#
#         rating_count
# count    1463.000000
# mean    18295.541353
# std     42753.864952
# min         2.000000
# 25%      1186.000000
# 50%      5179.000000
# 75%     17336.500000
# max    426973.000000

# %%
df[["discounted_price", "actual_price", "discount_percentage", "rating", "rating_count"]].describe()
# Out:
#        discounted_price   actual_price  discount_percentage       rating  \
# count       1465.000000    1465.000000          1465.000000  1464.000000
# mean        3125.310874    5444.990635            47.691468     4.096585
# std         6944.304394   10874.826864            21.635905     0.291674
# min           39.000000      39.000000             0.000000     2.000000
# 25%          325.000000     800.000000            32.000000     4.000000
# 50%          799.000000    1650.000000            50.000000     4.100000
# 75%         1999.000000    4295.000000            63.000000     4.300000
# max        77990.000000  139900.000000            94.000000     5.000000
#
#         rating_count
# count    1463.000000
# mean    18295.541353
# std     42753.864952
# min         2.000000
# 25%      1186.000000
# 50%      5179.000000
# 75%     17336.500000
# max    426973.000000

# %%
df["discount_value"] = df["actual_price"] - df["discounted_price"]

df[["actual_price", "discounted_price", "discount_value"]].head()
# Out:
#    actual_price  discounted_price  discount_value
# 0        1099.0             399.0           700.0
# 1         349.0             199.0           150.0
# 2        1899.0             199.0          1700.0
# 3         699.0             329.0           370.0
# 4         399.0             154.0           245.0

# %%
df[["product_name", "category", "actual_price", "discounted_price", "discount_value", "discount_percentage"]].sort_values(
    by="discount_value",
    ascending=False
).head(10)
# Out:
#                                            product_name  \
# 249   Sony Bravia 164 cm (65 inches) 4K Ultra HD Sma...
# 1182  Coway Professional Air Purifier for Home, Long...
# 568   Samsung Galaxy S20 FE 5G (Cloud Navy, 8GB RAM,...
# 150   VU 138 cm (55 inches) Premium Series 4K Ultra ...
# 1354  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...
# 1306  ECOVACS DEEBOT N8 2-in-1 Robotic Vacuum Cleane...
# 283   LG 139 cm (55 inches) 4K Ultra HD Smart LED TV...
# 255   VU 164 cm (65 inches) The GloLED Series 4K Sma...
# 108   VU 139 cm (55 inches) The GloLED Series 4K Sma...
# 323   TCL 108 cm (43 inches) 4K Ultra HD Certified A...
#
#                                                category  actual_price  \
# 249   Electronics|HomeTheater,TV&Video|Televisions|S...      139900.0
# 1182  Home&Kitchen|Heating,Cooling&AirQuality|AirPur...       59900.0
# 568   Electronics|Mobiles&Accessories|Smartphones&Ba...       74999.0
# ...

# %%
df[["product_name", "category", "actual_price", "discounted_price", "discount_value", "discount_percentage"]].sort_values(
    by="discount_percentage",
    ascending=False
).head(10)
# Out:
#                                           product_name  \
# 695  rts [2 Pack] Mini USB C Type C Adapter Plug, T...
# 372  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 380  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 364  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 368  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 334  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 557  LAPSTER 12pcs Spiral Cable Protectors for Char...
# 920  Silicone Rubber Earbuds Tips, Eartips, Earpads...
# 644  Sounce Spiral Charger Cable Protector Data Cab...
# 407  Sounce Spiral Charger Cable Protector Data Cab...
#
#                                               category  actual_price  \
# 695  Computers&Accessories|Accessories&Peripherals|...        4999.0
# 372        Electronics|WearableTechnology|SmartWatches       19999.0
# 380        Electronics|WearableTechnology|SmartWatches       19999.0
# 364        Electronics|WearableTechnology|SmartWatches       19999.0
# ...

# %%
df["product_id"].nunique()
# Out:
# 1351

# %%
df["product_name"].nunique()
# Out:
# 1337

# %%
df["product_id"].value_counts().head(10)
# Out:
# product_id
# B07JW9H4J1    3
# B098NS6PVG    3
# B096MSW6CT    3
# B08HDJ86NZ    3
# B08CF3B7N1    3
# B08Y1TFSP6    3
# B08WRWPM22    3
# B08DDRGWTJ    3
# B08CF3D7QR    3
# B085DTN6R2    3
# Name: count, dtype: int64

# %%
df["product_name"].value_counts().head(10)
# Out:
# product_name
# Fire-Boltt Ninja Call Pro Plus 1.83" Smart Watch with Bluetooth Calling, AI Voice Assistance, 100 Sports Modes IP67 Rating, 240*280 Pixel High Resolution                                                  5
# Fire-Boltt Phoenix Smart Watch with Bluetooth Calling 1.3",120+ Sports Modes, 240*240 PX High Res with SpO2, Heart Rate Monitoring & IP67 Rating                                                           4
# Wayona Nylon Braided USB to Lightning Fast Charging and Data Sync Cable Compatible for iPhone 13, 12,11, X, 8, 7, 6, 5, iPad Air, Pro, Mini (3 FT Pack of 1, Grey)                                         3
# Ambrane Unbreakable 60W / 3A Fast Charging 1.5m Braided Type C Cable for Smartphones, Tablets, Laptops & other Type C devices, PD Technology, 480Mbps Data Sync, Quick Charge 3.0 (RCT15A, Black)          3
# ...

# %%
df_produtos = df.drop_duplicates(subset="product_id")

df_produtos.shape
# Out:
# (1351, 17)

# %%
df_produtos["product_id"].nunique()
# Out:
# 1351

# %%
df_produtos[["product_name", "category", "actual_price", "discounted_price", "discount_value", "discount_percentage"]].sort_values(
    by="discount_percentage",
    ascending=False
).head(10)
# Out:
#                                            product_name  \
# 695   rts [2 Pack] Mini USB C Type C Adapter Plug, T...
# 364   Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 368   Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 372   Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 380   Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 334   Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 407   Sounce Spiral Charger Cable Protector Data Cab...
# 1026  beatXP Kitchen Scale Multipurpose Portable Ele...
# 2     Sounce Fast Phone Charging Cable & Data Sync U...
# 602   LAPSTER Spiral Charger Spiral Charger Cable Pr...
#
#                                                category  actual_price  \
# 695   Computers&Accessories|Accessories&Peripherals|...        4999.0
# 364         Electronics|WearableTechnology|SmartWatches       19999.0
# 368         Electronics|WearableTechnology|SmartWatches       19999.0
# ...

# %%
import pandas as pd

df = pd.read_csv("amazon.csv")

# %%
df_produtos = df.drop_duplicates(subset="product_id")

df_produtos.shape
# Out:
# (1351, 16)

# %%
import pandas as pd

df = pd.read_csv("amazon.csv")

df["discounted_price"] = df["discounted_price"].str.replace("₹", "", regex=False)
df["discounted_price"] = df["discounted_price"].str.replace(",", "", regex=False)
df["discounted_price"] = df["discounted_price"].astype(float)

df["actual_price"] = df["actual_price"].str.replace("₹", "", regex=False)
df["actual_price"] = df["actual_price"].str.replace(",", "", regex=False)
df["actual_price"] = df["actual_price"].astype(float)

df["discount_percentage"] = df["discount_percentage"].str.replace("%", "", regex=False)
df["discount_percentage"] = df["discount_percentage"].astype(float)

df["rating"] = pd.to_numeric(df["rating"], errors="coerce")

df["rating_count"] = df["rating_count"].str.replace(",", "", regex=False)
df["rating_count"] = df["rating_count"].astype(float)

df["discount_value"] = df["actual_price"] - df["discounted_price"]

df_produtos = df.drop_duplicates(subset="product_id")

df_produtos.shape
# Out:
# (1351, 17)

# %%
df_produtos.groupby("category")[["discount_percentage", "discount_value", "rating", "rating_count"]].mean().sort_values(
    by="discount_percentage",
    ascending=False
).head(10)
# Out:
#                                                     discount_percentage  \
# category
# Computers&Accessories|Accessories&Peripherals|C...                 90.0
# Electronics|Headphones,Earbuds&Accessories|Earpads                 90.0
# Electronics|Mobiles&Accessories|MobileAccessori...                 90.0
# Electronics|Headphones,Earbuds&Accessories|Adap...                 88.0
# Computers&Accessories|Accessories&Peripherals|K...                 87.5
# Electronics|Mobiles&Accessories|MobileAccessori...                 82.0
# Computers&Accessories|Components|InternalHardDr...                 80.0
# Computers&Accessories|Accessories&Peripherals|A...                 78.5
# Electronics|Mobiles&Accessories|MobileAccessori...                 76.4
# Electronics|Headphones,Earbuds&Accessories|Cases                   76.0
#
#                                                     discount_value  rating  \
# category
# Computers&Accessories|Accessories&Peripherals|C...           900.0    4.05
# ...

# %%
df_produtos["main_category"] = df_produtos["category"].str.split("|").str[0]

df_produtos[["category", "main_category"]].head()
# Out:
#                                             category          main_category
# 0  Computers&Accessories|Accessories&Peripherals|...  Computers&Accessories
# 1  Computers&Accessories|Accessories&Peripherals|...  Computers&Accessories
# 2  Computers&Accessories|Accessories&Peripherals|...  Computers&Accessories
# 3  Computers&Accessories|Accessories&Peripherals|...  Computers&Accessories
# 4  Computers&Accessories|Accessories&Peripherals|...  Computers&Accessories

# %%
df_produtos.groupby("main_category")[["discount_percentage", "discount_value", "rating", "rating_count"]].mean().sort_values(
    by="discount_percentage",
    ascending=False
)
# Out:
#                        discount_percentage  discount_value    rating  \
# main_category
# HomeImprovement                  57.500000      462.000000  4.250000
# Computers&Accessories            53.224000      910.256693  4.153867
# Health&PersonalCare              53.000000     1001.000000  4.000000
# Electronics                      49.906122     4192.214286  4.077755
# MusicalInstruments               46.000000      709.000000  3.900000
# Car&Motorbike                    42.000000     1661.000000  3.800000
# Home&Kitchen                     40.120536     1831.458013  4.040716
# OfficeProducts                   12.354839       95.612903  4.309677
# Toys&Games                        0.000000        0.000000  4.300000
#
#                        rating_count
# main_category
# HomeImprovement         4283.000000
# Computers&Accessories  16984.388740
# Health&PersonalCare     3663.000000
# Electronics            28996.746939
# MusicalInstruments     44441.000000
# ...

# %%
df_produtos["main_category"].value_counts()
# Out:
# main_category
# Electronics              490
# Home&Kitchen             448
# Computers&Accessories    375
# OfficeProducts            31
# MusicalInstruments         2
# HomeImprovement            2
# Toys&Games                 1
# Car&Motorbike              1
# Health&PersonalCare        1
# Name: count, dtype: int64
